# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
I = imread('/content/drive/MyDrive/IBM/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/22e6ab6c-375c-475f-8888-3d2f6d939111___RS_HL 7625.JPG')
J = imread('/content/drive/MyDrive/IBM/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/2a4cbd85-e831-4ec4-8acf-49cea51eeb5f___JR_FrgE.S 2900.JPG')

# %%
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.subplot(122), plt.imshow(J)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(np.abs(I[:, :, 0].astype(float) - J[:, :, 0].astype(float)), cmap='gray')
plt.show()

# %%
d = imread('/content/drive/MyDrive/IBM/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___healthy/22e6ab6c-375c-475f-8888-3d2f6d939111___RS_HL 7625.JPG')
mask = imread('/content/drive/MyDrive/IBM/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/2a4cbd85-e831-4ec4-8acf-49cea51eeb5f___JR_FrgE.S 2900.JPG')

print(np.amin(d), np.amax(d))
print(np.amin(mask), np.amax(mask))
# Out:
# 0 238
# 0 255

# %%
plt.figure(), plt.imshow(mask), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

# %%
mask = mask[:, :, 0]

# %%
maskInv = np.zeros_like(mask)
maskInv[mask == 0] = 255
maskInv[mask == 255] = 0
plt.figure(), plt.imshow(maskInv, cmap='gray'), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)
